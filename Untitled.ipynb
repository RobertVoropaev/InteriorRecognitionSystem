# %%
#System
import os
import shutil

#Base
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import cv2
import random
from skimage.io import imread, imshow, imsave


#Seed
seed = 99
np.random.seed(seed)
random.seed(seed)

# %%
data = pd.read_csv("callbacks/Unet0/logger.csv")

# %%
plt.plot(data.epoch, data.dice_coef)
